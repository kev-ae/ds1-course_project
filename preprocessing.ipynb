# %%
import pandas as pd
df = pd.read_csv("dataset.csv", index_col=0)

# %%
df = df.drop_duplicates(subset=['track_id'], keep='first')

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df = df.drop(range(1000, len(df)))
df
# Out:
#                    track_id  \
# 0    3WHeau3uOtXi19dy61WCkI
# 1    3G3zSDVf90d1V4ICNrLugQ
# 2    4vBk67mVsxz5tZ1LMMTkd9
# 3    33ogSAFEaV8FZPIHG3rF0a
# 4    6iCsWX6pKlyzpTf8QrCdfx
# ..                      ...
# 995  1K4OfBFaLleSUaUVjp1l2X
# 996  0CbLgEZVmu8tz4HaZhvKxG
# 997  4M3RrZ3vL9nopiHsPHpsCy
# 998  0IqCoZ168iRc9LqfrYgpZy
# 999  67TQGw4cZzFD33j4KJcOdQ
#
#                                                artists  \
# 0                                            War Angel
# 1                                  Pappo;Ricardo Iorio
# 2    BaianaSystem;Buguinha Dub;Orquestra Afrosinfônica
# 3                                ODZ;Young Earth Sauce
# 4                                              Colombo
# ..                                                 ...
# 995                               ilyTOMMY;Savage Ga$p
# 996                                      The Jackson 5
# 997                                        S3RL;J0hnny
# 998                                Camilo;Shawn Mendes
# ...

# %%
df.to_csv('preproc.csv', index=False)

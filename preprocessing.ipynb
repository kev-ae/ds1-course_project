# %%
import pandas as pd
df = pd.read_csv("dataset.csv", index_col=0)

# %%
df = df.drop_duplicates(subset=['track_id'], keep='first')

# %%
'''df = df.sample(frac=1).reset_index(drop=True)'''

# %%
df = df.head(10000)
df
# Out:
#                      track_id                     artists  \
# idx
# 20001  3nqQXoyQOWXiESFLlDF1hG        Sam_Smith;Kim_Petras
# 51664  2tTmW7RDtMQtBk7m2rYeSw            Bizarrap;Quevedo
# 20008  4uUG5RXrOk84mYEfFvj3cK     David_Guetta;Bebe_Rexha
# 67356  5ww2BF9slyYgNOk37BlC4u               Manuel_Turizo
# 67358  6Sq7ltF9Qa7SNFBsV5Cogx  Bad_Bunny;Chencho_Corleone
# ...                       ...                         ...
# 18016  3IQSYqnKsCTMLWn2xE3HFT    The_Lonely_Island;T-Pain
# 18401  3USOTQdPtZlgVurwaqsdI5                 Tenacious_D
# 19663  1PpbrbgsXRXeKw1GnZMEv7                Don_Williams
# 19804  77Bt2DXJE1R1qsnm4D10Ox                    Seaforth
# 19852  11y8GSP2ASv8S9n0FiiDva                Juice_Newton
#
#                                   album_name  \
# idx
# 20001              Unholy (feat. Kim Petras)
# 51664  Quevedo: Bzrp Music Sessions, Vol. 52
# 20008                        I'm Good (Blue)
# 67356                             La Bachata
# 67358                       Un Verano Sin Ti
# ...                                      ...
# 18016                             Incredibad
# 18401                            Tenacious D
# 19663                       I Believe In You
# 19804                               Breakups
# 19852                                  Juice
#
#                                   track_name  popularity  duration_ms  \
# idx
# 20001              Unholy (feat. Kim Petras)         100       156943
# 51664  Quevedo: Bzrp Music Sessions, Vol. 52          99       198937
# 20008                        I'm Good (Blue)          98       175238
# 67356                             La Bachata          98       162637
# 67358                        Me Porto Bonito          97       178567
# ...                                      ...         ...          ...
# 18016                          I'm On A Boat          59       156266
# 18401                        Fuck Her Gently          59       123666
# 19663                       I Believe In You          59       246440
# 19804                               Breakups          59       223129
# 19852                   Angel Of The Morning          59       250440
#
#        explicit  danceability  energy  key  loudness  mode  speechiness  \
# idx
# 20001     False         0.714   0.472    2    -7.375     1       0.0864
# 51664     False         0.621   0.782    2    -5.548     1       0.0440
# 20008      True         0.561   0.965    7    -3.673     0       0.0343
# 67356     False         0.835   0.679    7    -5.329     0       0.0364
# 67358      True         0.911   0.712    1    -5.105     0       0.0817
# ...         ...           ...     ...  ...       ...   ...          ...
# 18016      True         0.623   0.871    0    -2.403     1       0.2390
# 18401      True         0.521   0.297    2    -7.022     1       0.0351
# 19663     False         0.512   0.212    7   -21.426     1       0.0483
# 19804     False         0.531   0.552    1    -5.945     1       0.0309
# 19852     False         0.452   0.313    8    -9.309     1       0.0260
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# idx
# 20001       0.01300          0.000005    0.2660    0.238  131.121
# 51664       0.01250          0.033000    0.2300    0.550  128.033
# 20008       0.00383          0.000007    0.3710    0.304  128.040
# 67356       0.58300          0.000002    0.2180    0.850  124.980
# 67358       0.09010          0.000027    0.0933    0.425   92.005
# ...             ...               ...       ...      ...      ...
# 18016       0.04650          0.000000    0.1110    0.653  150.079
# 18401       0.73200          0.000000    0.2730    0.517  118.681
# 19663       0.88000          0.005730    0.1150    0.510  117.756
# 19804       0.43600          0.000000    0.0786    0.328   74.931
# 19852       0.43300          0.000026    0.0772    0.344   75.806
#
#        time_signature track_genre
# idx
# 20001               4       dance
# 51664               4     hip-hop
# 20008               4       dance
# 67356               4       latin
# 67358               4       latin
# ...               ...         ...
# 18016               4      comedy
# 18401               4      comedy
# 19663               3     country
# 19804               3     country
# 19852               4     country
#
# [10000 rows x 20 columns]

# %%
df.to_csv('proc.csv', index=False)
